# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#load file 
file_to_load = 'bitcoin_data.csv'

#read file and load into pandas dataframe
price_data = pd.read_csv(file_to_load)
price_data.head()
# Out:
#         Start         End      Open      High       Low     Close  \
# 0  2024-12-26  2024-12-27  99792.00  99940.03  95249.51  95830.42
# 1  2024-12-25  2024-12-26  98612.37  99436.00  97676.75  99436.00
# 2  2024-12-24  2024-12-25  94736.64  99280.01  93712.18  98805.90
# 3  2024-12-23  2024-12-24  95181.30  96433.71  92587.99  94748.02
# 4  2024-12-22  2024-12-23  97178.72  97408.04  94288.04  95136.87
#
#          Volume    Market Cap
# 0  5.862097e+10  1.915420e+12
# 1  6.203616e+10  1.949705e+12
# 2  7.632318e+10  1.899057e+12
# 3  7.438945e+10  1.876386e+12
# 4  6.017203e+10  1.906303e+12

# %%
#re-order rows based on ascending data
price_data = price_data.sort_values(by=['End'])

# %%
price_data.info()
price_data['End'] = pd.to_datetime(price_data['End'])
price_data['Start'] =pd.to_datetime(price_data['Start'])
price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5277 entries, 5276 to 0
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Start       5277 non-null   object
#  1   End         5277 non-null   datetime64[ns]
#  2   Open        5277 non-null   float64
#  3   High        5277 non-null   float64
#  4   Low         5277 non-null   float64
#  5   Close       5277 non-null   float64
#  6   Volume      5277 non-null   float64
#  7   Market Cap  5277 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 371.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5277 entries, 5276 to 0
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Start       5277 non-null   datetime64[ns]
#  1   End         5277 non-null   datetime64[ns]
#  2   Open        5277 non-null   float64
# ...

# %%
plt.yscale('log')
plt.scatter(price_data.End, price_data.Close)
plt.show()

# %%
plt.plot(price_data['End'],price_data['Close'])
plt.xticks(price_data['End'])
plt.xlabel("Daily Close")
plt.ylabel('Price')
plt.title('Price vs Date')
plt.yscale('log')
plt.xscale('log')
plt.show()

#need to explore data sources...

# %%
#footnotes
# source data pulled from https://coincodex.com/crypto/bitcoin/historical-data/ on 12/26/2024

# %%
#what is happening early on in the timeline

early_price = price_data.head(1000)
early_price.head(250)
# Out:
#            Start         End    Open    High     Low   Close  Volume  \
# 5276  2010-07-17  2010-07-18  0.0500  0.0500  0.0500  0.0500     0.0
# 5275  2010-07-18  2010-07-19  0.0858  0.0858  0.0858  0.0858     0.0
# 5274  2010-07-19  2010-07-20  0.0808  0.0808  0.0808  0.0808     0.0
# 5273  2010-07-20  2010-07-21  0.0747  0.0747  0.0747  0.0747     0.0
# 5272  2010-07-21  2010-07-22  0.0792  0.0792  0.0792  0.0792     0.0
# ...          ...         ...     ...     ...     ...     ...     ...
# 5031  2011-03-19  2011-03-20  0.7650  0.7650  0.7650  0.7650     0.0
# 5030  2011-03-20  2011-03-21  0.7411  0.7411  0.7411  0.7411     0.0
# 5029  2011-03-21  2011-03-22  0.7590  0.7590  0.7590  0.7590     0.0
# 5028  2011-03-22  2011-03-23  0.8090  0.8090  0.8090  0.8090     0.0
# 5027  2011-03-23  2011-03-24  0.8497  0.8497  0.8497  0.8497     0.0
#
#         Market Cap
# 5276  1.708032e+05
# 5275  2.947466e+05
# 5274  2.775702e+05
# 5273  2.567102e+05
# 5272  2.743084e+05
# ...

# %%
# plotting the first 1,000 days
plt.xscale('log')
plt.yscale('log')
plt.scatter(early_price.End, early_price.Close)
plt.show()
